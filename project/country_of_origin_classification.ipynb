# %%
# ls | xargs cat >> dataset.csv
import numpy as np

# %%
def readfile(filename):
    file = open(filename, 'rt')
    original_text = file.read().splitlines()
    file.close()
    
    return original_text

# %%
# dataset = readfile('./dataset.csv')
dataset = readfile('./raw_data/names_List_of_Thais.csv')

# print(len(dataset))
data_len = len(dataset)

X_words = []
y = []
for line in dataset:
    line = line.replace('"','')
#     line = line.replace(' ','')
    name, origin = line.split(',')
    X_words.append(name)
    y.append(origin)

# print(X, y)

# %%
from sklearn.feature_extraction.text import CountVectorizer 

vectorizer = CountVectorizer(analyzer='char')

analyzer = vectorizer.build_analyzer()

# %%
X = []
for x in X_words:
    tokens = analyzer(x)
    X.append(tokens)
#     print(tokens)
              
X = np.array(X)
y = np.array(y)
# print(X)

from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
y_train, y_test = train_test_split(y, test_size=0.2, random_state=42)

# %%
print(X)
# Out:
# [list(['b', 'h', 'u', 'm', 'i', 'b', 'o', 'l', ' ', 'a', 'd', 'u', 'l', 'y', 'a', 'd', 'e', 'j'])
#  list(['p', 'o', 'n', 'g', 'p', 'o', 'l', ' ', 'a', 'd', 'i', 'r', 'e', 'k', 's', 'a', 'r', 'n'])
#  list(['p', 'i', 'y', 'a', 's', 'v', 'a', 's', 't', 'i', ' ', 'a', 'm', 'r', 'a', 'n', 'a', 'n', 'd'])
#  list(['t', 'h', 'a', 'n', 'o', 'n', 'g', ' ', 'b', 'i', 'd', 'a', 'y', 'a'])
#  list(['k', 'r', 'a', 'i', 's', 'a', 'k', ' ', 'c', 'h', 'o', 'o', 'n', 'h', 'a', 'v', 'a', 'n'])
#  list(['p', 'r', 'i', 'd', 'i', 'y', 'a', 't', 'h', 'o', 'r', 'n', ' ', 'd', 'e', 'v', 'a', 'k', 'u', 'l', 'a'])
#  list(['d', 'e', 'v', 'a', 'v', 'o', 'n', 'g', 's', 'e'])
#  list(['y', 'a', 't', ' ', 'h', 'w', 'a', 'i', 'd', 'i'])
#  list(['c', 'h', 'i', 'r', 'a', 'y', 'u', ' ', 'i', 's', 'a', 'r', 'a', 'n', 'g', 'k', 'u', 'l'])
#  list(['s', 'o', 'm', 'k', 'i', 'd', ' ', 'j', 'a', 't', 'u', 's', 'r', 'i', 'p', 'i', 't', 'a', 'k'])
#  list(['c', 'h', 'u', 'w', 'i', 't', ' ', 'k', 'a', 'm', 'o', 'l', 'v', 'i', 's', 'i', 't'])
#  list(['s', 'u', 'd', 'a', 'r', 'a', 't', ' ', 'k', 'e', 'y', 'u', 'r', 'a', 'p', 'h', 'a', 'n'])
#  list(['s', 'u', 'n', 't', 'h', 'o', 'r', 'n', ' ', 'k', 'o', 'n', 'g', 's', 'o', 'm', 'p', 'o', 'n', 'g'])
#  list(['c', 'h', 'u', 'a', 'n', ' ', 'l', 'e', 'e', 'k', 'p', 'a', 'i'])
#  list(['p', 'r', 'a', 'c', 'h', 'a', 'i', ' ', 'l', 'e', 'o', 'p', 'h', 'a', 'i', '-', 'r', 'a', 't', 'a', 'n', 'a'])
#  list(['p', 'r', 'o', 'm', 'm', 'i', 'n', ' ', 'l', 'e', 'r', 't', 's', 'u', 'r', 'i', 'd', 'e', 'j'])
#  list(['t', 'h', 'a', 'm', 'm', 'a', 'r', 'a', 'k', ' ', 'i', 's', 'a', 'r', 'a', 'g', 'u', 'r', 'a', ' ', 'n', 'a', ' ', 'a', 'y', 'u', 't', 'h', 'a', 'y', 'a'])
#  list(['p', 'a', 'l', 'l', 'o', 'p', ' ', 'p', 'i', 'n', 'm', 'a', 'n', 'e', 'e'])
#  list(['s', 'u', 'k', 'h', 'u', 'm', 'b', 'h', 'a', 'n', 'd', ' ', 'p', 'a', 'r', 'i', 'b', 'a', 't', 'r', 'a'])
#  list(['n', 'o', 'p', 'p', 'a', 'd', 'o', 'n', ' ', 'p', 'a', 't', 't', 'a', 'm', 'a'])
#  list(['r', 'a', 't', 's', 'a', 'd', 'a', 'n', 'u', 'p', 'r', 'a', 'd', 'i', 't', ' ', 'm', 'a', 'h', 'i', 's', 'o', 'n', ' ', 'p', 'h', 'a', 'k', 'd', 'i'])
#  list(['s', 'a', 'n', 'g', ' ', 'p', 'h', 'a', 't', 'h', 'a', 'n', 'o', 't', 'h', 'a', 'i'])
#  list(['n', 'i', 't', ' ', 'p', 'h', 'i', 'b', 'u', 'n', 's', 'o', 'n', 'g', 'k', 'h', 'r', 'a', 'm'])
#  list(['l', 'e', 'k', ' ', 'n', 'a', 'n', 'a'])
#  list(['m', 'o', 'n', 'g', 'k', 'o', 'l', ' ', 'n', 'a', ' ', 's', 'o', 'n', 'g', 'k', 'h', 'l', 'a'])
#  list(['s', 'u', 'r', 'i', 'n', ' ', 'p', 'i', 't', 's', 'u', 'w', 'a', 'n'])
#  list(['s', 'u', 't', 'h', 'a', 'm', ' ', 's', 'a', 'n', 'g', 'p', 'r', 'a', 't', 'h', 'u', 'm'])
#  list(['s', 'u', 'r', 'a', 'k', 'i', 'a', 'r', 't', ' ', 's', 'a', 't', 'h', 'i', 'r', 'a', 't', 'h', 'a', 'i'])
#  list(['t', 'h', 'a', 'w', 'o', 'r', 'n', ' ', 's', 'e', 'n', 'n', 'i', 'a', 'm'])
#  list(['b', 'o', 'o', 'n', 's', 'a', 'n', 'o', 'n', 'g', ' ', 'p', 'u', 'n', 'y', 'o', 'd', 'y', 'a', 'n', 'a'])
#  list(['b', 'o', 'o', 'n', 'c', 'h', 'u', ' ', 'r', 'o', 'j', 'a', 'n', 'a', 's', 't', 'i', 'e', 'n'])
#  list(['m', 'a', 'n', 'o', 'o', 'n', 'k', 'r', 'i', 't', ' ', 'r', 'o', 'o', 'p', 'k', 'a', 'c', 'h', 'o', 'r', 'n'])
#  list(['k', 'a', 'r', 'o', 'o', 'n', ' ', 's', 'a', 'i', '-', 'n', 'g', 'a', 'm'])
#  list(['c', 'h', 'a', 't', 'u', 'm', 'o', 'n', 'g', 'o', 'l', ' ', 's', 'o', 'n', 'a', 'k', 'u', 'l'])
#  list(['p', 'r', 'a', 's', 'o', 'n', 'g', ' ', 's', 'o', 'o', 'n', 's', 'i', 'r', 'i'])
#  list(['c', 'h', 'a', 'm', 'l', 'o', 'n', 'g', ' ', 's', 'r', 'i', 'm', 'u', 'a', 'n', 'g'])
#  list(['w', 'i', 'j', 'i', 't', ' ', 's', 'r', 'i', 's', 'a', '-', 'a', 'r', 'n'])
#  list(['s', 'a', 'm', 'a', 'k', ' ', 's', 'u', 'n', 'd', 'a', 'r', 'a', 'v', 'e', 'j'])
#  list(['k', 'a', 'n', 't', 'a', 't', 'h', 'i', ' ', 's', 'u', 'p', 'h', 'a', 'm', 'o', 'n', 'g', 'k', 'h', 'o', 'n'])
#  list(['c', 'h', 'a', 'l', 'o', 'n', 'g', 'p', 'h', 'o', 'b', ' ', 's', 'u', 's', 's', 'a', 'n', 'g', 'k', 'a', 'r', 'n'])
#  list(['s', 'a', 'n', 't', 'i', ' ', 't', 'h', 'a', 'k', 'r', 'a', 'l'])
#  list(['p', 'u', 'e', 'y', ' ', 'u', 'n', 'g', 'p', 'a', 'k', 'o', 'r', 'n'])
#  list(['p', 'r', 'a', 't', 'e', 'e', 'p', ' ', 'u', 'n', 'g', 's', 'o', 'n', 'g', 't', 'h', 'a', 'm', ' ', 'h', 'a', 't', 'a'])
#  list(['b', 'o', 'r', 'w', 'o', 'r', 'n', 's', 'a', 'k', ' ', 'u', 'w', 'a', 'n', 'n', 'o'])
#  list(['a', 'b', 'h', 'i', 's', 'i', 't', ' ', 'v', 'e', 'j', 'j', 'a', 'j', 'i', 'v', 'a'])
#  list(['m', 'e', 'c', 'h', 'a', 'i', ' ', 'v', 'i', 'r', 'a', 'v', 'a', 'i', 'd', 'y', 'a'])
#  list(['s', 'a', 'n', 'g', 'u', 'a', 'n', ' ', 't', 'u', 'l', 'a', 'r', 'a', 'k', 's', 'a'])
#  list(['c', 'h', 'i', 't', 'c', 'h', 'a', 'i', ' ', 'w', 'a', 'n', 'n', 'a', 's', 'a', 't', 'h', 'i', 't'])
#  list(['k', 'o', 'w', 'i', 't', ' ', 'w', 'a', 't', 't', 'a', 'n', 'a'])
#  list(['l', 'u', 'a', 'n', 'g', ' ', 'w', 'i', 'c', 'h', 'i', 't', 'w', 'a', 't', 'h', 'a', 'k', 'a', 'n'])
#  list(['t', 'a', 'm', 'm', 'y', ' ', 'd', 'u', 'c', 'k', 'w', 'o', 'r', 't', 'h'])
#  list(['p', 'l', 'o', 'y', 'p', 'a', 'i', 'l', 'i', 'n', ' ', 'm', 'a', 'h', 'i', 'd', 'o', 'l', ' ', 'j', 'e', 'n', 's', 'e', 'n'])
#  list(['s', 'i', 'r', 'i', 'k', 'i', 't', 'i', 'y', 'a', ' ', 'j', 'e', 'n', 's', 'e', 'n'])
#  list(['j', 'o', 'h', 'n', ' ', 'p', 'i', 'p', 'p', 'y'])
#  list(['m', 'e', 'c', 'h', 'a', 'i', ' ', 'v', 'i', 'r', 'a', 'v', 'a', 'i', 'd', 'y', 'a'])
#  list(['s', 'u', 'l', 't', 'a', 'n', ' ', 'i', 's', 'm', 'a', 'i', 'l', ' ', 'n', 'a', 's', 'i', 'r', 'u', 'd', 'd', 'i', 'n', ' ', 's', 'h', 'a', 'h'])
#  list(['t', 'u', 'n', 'k', 'u', ' ', 'a', 'b', 'd', 'u', 'l', ' ', 'r', 'a', 'h', 'm', 'a', 'n'])
#  list(['t', 'h', 'a', 'k', 's', 'i', 'n', ' ', 's', 'h', 'i', 'n', 'a', 'w', 'a', 't', 'r', 'a'])
#  list(['a', 'k', 'a', 'r', 'a', ' ', 'a', 'm', 'a', 'r', 't', 't', 'a', 'y', 'a', 'k', 'u', 'l'])
#  list(['a', 'l', 'e', 'x', ' ', 'r', 'e', 'n', 'd', 'e', 'l', 'l'])
#  list(['a', 'm', 'a', 'r', 'a', ' ', 'a', 's', 'a', 'v', 'a', 'n', 'a', 'n', 'd', 'a'])
#  list(['a', 'm', 'p', 'h', 'o', 'l', ' ', 'l', 'a', 'm', 'p', 'o', 'o', 'n'])
#  list(['a', 'n', 'a', 'n', ' ', 'a', 'n', 'w', 'a', 'r'])
#  list(['a', 'n', 'a', 'n', 'd', 'a', ' ', 'e', 'v', 'e', 'r', 'i', 'n', 'g', 'h', 'a', 'm'])
#  list(['a', 'n', 'd', 'r', 'e', 'a', ' ', 's', 'u', 'á', 'r', 'e', 'z', ' ', '(', 't', 'h', 'a', 'i', ' ', 's', 'i', 'n', 'g', 'e', 'r', ')'])
#  list(['a', 'n', 'n', ' ', 't', 'h', 'o', 'n', 'g', 'p', 'r', 'a', 's', 'o', 'm'])
#  list(['a', 'p', 'a', 's', 'i', 'r', 'i', ' ', 'n', 'i', 't', 'i', 'b', 'h', 'o', 'n'])
#  list(['a', 'r', 'a', 'n', 'y', 'a', ' ', 'n', 'a', 'm', 'w', 'o', 'n', 'g'])
#  list(['a', 'r', 'a', 'y', 'a', ' ', 'a', '.', ' ', 'h', 'a', 'r', 'g', 'a', 't', 'e'])
#  list(['a', 'r', 'e', 'e', 'y', 'a', ' ', 'c', 'h', 'u', 'm', 's', 'a', 'i'])
#  list(['b', 'a', 'm', 'b', 'a', 'm', ' ', '(', 's', 'i', 'n', 'g', 'e', 'r', ')'])
#  list(['b', 'i', 'l', 'l', 'y', ' ', 'o', 'g', 'a', 'n'])
#  list(['b', 'o', 'n', 'g', 'k', 'o', 'j', ' ', 'k', 'h', 'o', 'n', 'g', 'm', 'a', 'l', 'a', 'i'])
#  list(['c', 'a', 'r', 'i', 's', 's', 'a', ' ', 's', 'p', 'r', 'i', 'n', 'g', 'e', 't', 't'])
#  list(['c', 'a', 'r', 'o', 'l', 'i', 'n', 'e', ' ', 'd', 'e', 's', 'n', 'e', 'i', 'g', 'e', 's'])
#  list(['c', 'h', 'a', 'k', 'r', 'i', 't', ' ', 'y', 'a', 'm', 'n', 'a', 'm'])
#  list(['c', 'h', 'a', 'l', 'i', 't', 'a', ' ', 's', 'u', 'a', 'n', 's', 'a', 'n', 'e'])
#  list(['c', 'h', 'a', 'r', 'l', 'i', 'e', ' ', 't', 'r', 'a', 'i', 'r', 'a', 't'])
#  list(['c', 'h', 'a', 'r', 't', 'c', 'h', 'a', 'i', ' ', 'n', 'g', 'a', 'm', 's', 'a', 'n'])
#  list(['c', 'h', 'a', 't', 'c', 'h', 'a', 'i', ' ', 'p', 'l', 'e', 'n', 'g', 'p', 'a', 'n', 'i', 'c', 'h'])
#  list(['c', 'h', 'a', 't', 't', 'a', 'p', 'o', 'n', 'g', ' ', 'p', 'a', 'n', 't', 'a', 'n', 'a', '-', 'a', 'n', 'g', 'k', 'u', 'l'])
#  list(['c', 'h', 'i', 'n', 'a', 'w', 'u', 't', ' ', 'i', 'n', 'd', 'r', 'a', 'c', 'u', 's', 'i', 'n'])
#  list(['c', 'h', 'i', 'n', 't', 'a', 'r', 'a', ' ', 's', 'u', 'k', 'a', 'p', 'a', 't', 'a', 'n', 'a'])
#  list(['c', 'r', 'i', 's', ' ', 'h', 'o', 'r', 'w', 'a', 'n', 'g'])
#  list(['c', 'h', 'r', 'i', 's', 's', 'y', ' ', 't', 'e', 'i', 'g', 'e', 'n'])
#  list(['c', 'h', 'r', 'i', 's', 't', 'i', 'n', 'a', ' ', 'a', 'g', 'u', 'i', 'l', 'a', 'r'])
#  list(['c', 'h', 'r', 'i', 's', 't', 'y', ' ', 'g', 'i', 'b', 's', 'o', 'n'])
#  list(['c', 'i', 'n', 'd', 'y', ' ', 'b', 'u', 'r', 'b', 'r', 'i', 'd', 'g', 'e'])
#  list(['d', 'a', 'v', 'i', 'k', 'a', ' ', 'h', 'o', 'o', 'r', 'n', 'e'])
#  list(['f', 'a', 'r', 'i', 'd', 'a', ' ', 'w', 'a', 'l', 'l', 'e', 'r'])
#  list(['f', 'l', 'o', 'r', 'e', 'n', 'c', 'e', ' ', 'v', 'a', 'n', 'i', 'd', 'a', ' ', 'f', 'a', 'i', 'v', 'r', 'e'])
#  list(['g', 'e', 'n', 'a', ' ', 'd', 'e', 's', 'o', 'u', 'z', 'a'])
#  list(['h', 'u', 'g', 'o', ' ', '(', 'm', 'u', 's', 'i', 'c', 'i', 'a', 'n', ')'])
#  list(['i', 'n', 't', 'i', 'r', 'a', ' ', 'c', 'h', 'a', 'r', 'o', 'e', 'n', 'p', 'u', 'r', 'a'])
#  list(['j', 'a', 'm', 'e', 's', ' ', 'm', 'a'])
#  list(['j', 'a', 'n', 'i', 'e', ' ', 't', 'i', 'e', 'n', 'p', 'h', 'o', 's', 'u', 'w', 'a', 'n'])
#  list(['j', 'a', 'n', 'n', 'i', 'n', 'e', ' ', 'w', 'e', 'i', 'g', 'e', 'l'])
#  list(['j', 'a', 's', 'o', 'n', ' ', 'y', 'o', 'u', 'n', 'g', ' ', '(', 'a', 'c', 't', 'o', 'r', ')'])
#  list(['j', 'e', 's', 'd', 'a', 'p', 'o', 'r', 'n', ' ', 'p', 'h', 'o', 'l', 'd', 'e', 'e'])
#  list(['j', 'e', 's', 's', 'i', 'c', 'a', ' ', 'p', 'a', 's', 'a', 'p', 'h', 'a', 'n'])
#  list(['j', 'e', 't', 'r', 'i', 'n', ' ', 'w', 'a', 't', 't', 'a', 'n', 'a', 's', 'i', 'n'])
#  list(['j', 'i', 'n', 't', 'a', 'r', 'a', ' ', 'p', 'o', 'o', 'n', 'l', 'a', 'r', 'p'])
#  list(['j', 'i', 'r', 'a', 'y', 'u', ' ', 't', 'a', 'n', 'g', 's', 'r', 'i', 's', 'u', 'k'])
#  list(['j', 'o', 'c', 'e', 'l', 'y', 'n', ' ', 's', 'e', 'a', 'g', 'r', 'a', 'v', 'e'])
#  list(['j', 'o', 'e', 'y', ' ', 'c', 'h', 'e', 'r', 'n', 'y', 'i', 'm'])
#  list(['j', 'o', 'h', 'n', 'n', 'y', ' ', 'a', 'n', 'f', 'o', 'n', 'e'])
#  list(['j', 'o', 'n', 'a', 's', ' ', 'a', 'n', 'd', 'e', 'r', 's', 'o', 'n'])
#  list(['j', 'o', 'n', 'i', ' ', 'a', 'n', 'w', 'a', 'r'])
#  list(['k', 'a', 't', 'h', 'a', 'l', 'e', 'e', 'y', 'a', ' ', 'm', 'c', 'i', 'n', 't', 'o', 's', 'h'])
#  list(['k', 'a', 't', 'r', 'e', 'e', 'y', 'a', ' ', 'e', 'n', 'g', 'l', 'i', 's', 'h'])
#  list(['k', 'e', 's', 'a', 'r', 'i', 'n', ' ', 'c', 'h', 'a', 'i', 'c', 'h', 'a', 'l', 'e', 'r', 'm', 'p', 'o', 'l'])
#  list(['k', 'e', 's', 's', 'a', 'r', 'i', 'n', ' ', 'e', 'k', 't', 'a', 'w', 'a', 't', 'k', 'u', 'l'])
#  list(['k', 'h', 'e', 'm', 'a', 'n', 'i', 't', ' ', 'j', 'a', 'm', 'i', 'k', 'o', 'r', 'n'])
#  list(['k', 'h', 'e', 'm', 'u', 'p', 's', 'o', 'r', 'n', ' ', 's', 'i', 'r', 'i', 's', 'u', 'k', 'h', 'a'])
#  list(['k', 'i', 'm', 'b', 'e', 'r', 'l', 'e', 'y', ' ', 'a', 'n', 'n', 'e', ' ', 'w', 'o', 'l', 't', 'e', 'm', 'a', 's'])
#  list(['k', 'r', 'i', 's', 's', 'a', 'd', 'a', ' ', 't', 'e', 'r', 'r', 'e', 'n', 'c', 'e'])
#  list(['k', 'r', 'y', 's', 't', 'a', 'l', ' ', 'v', 'e', 'e'])
#  list(['l', 'a', 'i', 'l', 'a', ' ', 'b', 'o', 'o', 'n', 'y', 'a', 's', 'a', 'k'])
#  list(['l', 'a', 'l', 'i', 't', 'a', ' ', 'p', 'a', 'n', 'y', 'o', 'p', 'a', 's'])
#  list(['l', 'a', 'n', 'n', 'a', ' ', 'c', 'o', 'm', 'm', 'i', 'n', 's'])
#  list(['l', 'e', 'n', 'a', ' ', 'c', 'h', 'r', 'i', 's', 't', 'e', 'n', 's', 'e', 'n'])
#  list(['l', 'e', 'o', ' ', 's', 'a', 'u', 's', 's', 'a', 'y'])
#  list(['l', 'i', 's', 'a']) list(['l', 'o', 'r', ' ', 't', 'o', 'k'])
#  list(['m', 'a', 'i', ' ', 'c', 'h', 'a', 'r', 'o', 'e', 'n', 'p', 'u', 'r', 'a'])
#  list(['m', 'a', 'r', 'i', 'a', ' ', 'l', 'y', 'n', 'n', ' ', 'e', 'h', 'r', 'e', 'n'])
#  list(['m', 'a', 'r', 'i', 'e', ' ', 'e', 'u', 'g', 'e', 'n', 'i', 'e', ' ', 'l', 'e', ' ', 'l', 'a', 'y'])
#  list(['m', 'a', 'r', 'i', 'o', ' ', 'm', 'a', 'u', 'r', 'e', 'r'])
#  list(['m', 'a', 'r', 's', 'h', 'a', ' ', 'w', 'a', 't', 't', 'a', 'n', 'a', 'p', 'a', 'n', 'i', 'c', 'h'])
#  list(['m', 'e', 't', 'i', 'n', 'e', 'e', ' ', 'k', 'i', 'n', 'g', 'p', 'a', 'y', 'o', 'm'])
#  list(['m', 'i', 'c', 'h', 'a', 'e', 'l', ' ', 'c', 'h', 'a', 't', 'u', 'r', 'a', 'n', 't', 'a', 'b', 'u', 't'])
#  list(['m', 'i', 'c', 'h', 'a', 'e', 'l', ' ', 's', 'h', 'a', 'o', 'w', 'a', 'n', 'a', 's', 'a', 'i'])
#  list(['m', 'i', 't', 'r', ' ', 'c', 'h', 'a', 'i', 'b', 'a', 'n', 'c', 'h', 'a'])
#  list(['m', 'o', 'r', 'a', 'k', 'o', 't', ' ', 's', 'a', 'n', 'g', 't', 'a', 'w', 'e', 'e', 'p'])
#  list(['m', 'y', 'r', 'a', ' ', 'm', 'o', 'l', 'l', 'o', 'y'])
#  list(['m', 'y', 'r', 'i', 'a', ' ', 'b', 'e', 'n', 'e', 'd', 'e', 't', 't', 'i'])
#  list(['n', 'a', 'd', 'e', 'c', 'h', ' ', 'k', 'u', 'g', 'i', 'm', 'i', 'y', 'a'])
#  list(['n', 'a', 'm', 't', 'h', 'i', 'p', ' ', 'j', 'o', 'n', 'g', 'r', 'a', 'c', 'h', 'a', 't', 'a', 'w', 'i', 'b', 'o', 'o', 'n'])
#  list(['n', 'a', 'p', 'a', 'k', 'p', 'a', 'p', 'h', 'a', ' ', 'n', 'a', 'k', 'p', 'r', 'a', 's', 'i', 't', 't', 'e'])
#  list(['n', 'a', 'p', 'h', 'a', 't', ' ', 's', 'i', 'a', 'n', 'g', 's', 'o', 'm', 'b', 'o', 'o', 'n'])
#  list(['n', 'i', 'c', 'h', 'k', 'h', 'u', 'n', ' ', 'h', 'o', 'r', 'v', 'e', 'j', 'k', 'u', 'l'])
#  list(['n', 'i', 'c', 'o', 'l', 'e', ' ', 't', 'h', 'e', 'r', 'i', 'a', 'u', 'l', 't'])
#  list(['n', 'i', 'c', 'o', 'l', 'e', 'n', 'e', ' ', 'p', 'i', 'c', 'h', 'a', 'p', 'a', ' ', 'l', 'i', 'm', 's', 'n', 'u', 'k', 'a', 'n'])
#  list(['n', 'i', 't', 't', 'h', 'a', ' ', 'j', 'i', 'r', 'a', 'y', 'u', 'n', 'g', 'y', 'u', 'r', 'n'])
#  list(['o', 'd', 'e', 't', 't', 'e', ' ', 'h', 'e', 'n', 'r', 'i', 'e', 't', 't', 'e', ' ', 'j', 'a', 'c', 'q', 'm', 'i', 'n'])
#  list(['p', 'a', 'c', 'h', 'r', 'a', 'p', 'a', ' ', 'c', 'h', 'a', 'i', 'c', 'h', 'u', 'a'])
#  list(['p', 'a', 'k', 'o', 'r', 'n', ' ', 'c', 'h', 'a', 't', 'b', 'o', 'r', 'i', 'r', 'a', 'k'])
#  list(['p', 'a', 'k', 'o', 'r', 'n', ' ', 'l', 'u', 'm'])
#  list(['p', 'a', 'l', 'm', 'y'])
#  list(['p', 'a', 't', 'h', 'a', 'r', 'a', 'w', 'a', 'r', 'i', 'n', ' ', 't', 'i', 'm', 'k', 'u', 'l'])
#  list(['p', 'a', 't', 'i', 'p', 'a', 'r', 'n', ' ', 'p', 'a', 't', 'a', 'w', 'e', 'e', 'k', 'a', 'r', 'n'])
#  list(['p', 'a', 'u', 'l', 'a', ' ', 't', 'a', 'y', 'l', 'o', 'r'])
#  list(['p', 'e', 'r', 'a', 'n', 'e', 'e', ' ', 'k', 'o', 'n', 'g', 't', 'h', 'a', 'i'])
#  list(['p', 'e', 't', 'c', 'h', 'a', 'r', 'a', ' ', 'c', 'h', 'a', 'o', 'w', 'a', 'r', 'a', 't'])
#  list(['p', 'e', 't', 'c', 'h', 't', 'a', 'i', ' ', 'w', 'o', 'n', 'g', 'k', 'a', 'm', 'l', 'a', 'o'])
#  list(['p', 'e', 't', 'e', 'r', ' ', 'c', 'o', 'r', 'p', ' ', 'd', 'y', 'r', 'e', 'n', 'd', 'a', 'l'])
#  list(['p', 'h', 'i', 'y', 'a', 'd', 'a', ' ', 'a', 'k', 'k', 'r', 'a', 's', 'e', 'r', 'a', 'n', 'e', 'e'])
#  list(['p', 'h', 'u', 'w', 'a', 'r', 'y', 'n', 'e', ' ', 'k', 'e', 'e', 'n', 'a', 'n'])
#  list(['p', 'i', 's', 'u', 't', ' ', 'p', 'r', 'a', 'e', 's', 'a', 'n', 'g', 'e', 'a', 'm'])
#  list(['p', 'i', 't', 'c', 'h', 'a', 'n', 'a', 'r', 't', ' ', 's', 'a', 'k', 'a', 'k', 'o', 'r', 'n'])
#  list(['p', 'o', 'n', 'g', 'p', 'a', 't', ' ', 'w', 'a', 'c', 'h', 'i', 'r', 'a', 'b', 'u', 'n', 'j', 'o', 'n', 'g'])
#  list(['p', 'o', 'n', 'g', 's', 'a', 'k', ' ', 'r', 'a', 't', 't', 'a', 'n', 'a', 'p', 'o', 'n', 'g'])
#  list(['p', 'o', 'r', 'n', 't', 'i', 'p', ' ', 'n', 'a', 'k', 'h', 'i', 'r', 'u', 'n', 'k', 'a', 'n', 'o', 'k'])
#  list(['p', 'o', 'r', 'n', 't', 'i', 'p', ' ', 'p', 'a', 'p', 'a', 'n', 'a', 'i'])
#  list(['p', 'r', 'a', 'y', 'a', ' ', 'l', 'u', 'n', 'd', 'b', 'e', 'r', 'g'])
#  list(['p', 'r', 'i', 'n', ' ', 's', 'u', 'p', 'a', 'r', 'a', 't'])
#  list(['p', 'u', 'm', 'w', 'a', 'r', 'e', 'e', ' ', 'y', 'o', 'd', 'k', 'a', 'm', 'o', 'l'])
#  list(['r', 'a', 'n', 'e', 'e', ' ', 'c', 'a', 'm', 'p', 'e', 'n'])
#  list(['r', 'a', 's', 'r', 'i', ' ', 'b', 'a', 'l', 'e', 'n', 'c', 'i', 'a', 'g', 'a'])
#  list(['r', 'a', 'y', ' ', 'm', 'a', 'c', 'd', 'o', 'n', 'a', 'l', 'd'])
#  list(['r', 'h', 'a', 't', 'h', 'a', ' ', 'p', 'h', 'o', 'n', 'g', 'a', 'm'])
#  list(['s', 'a', 'd', 'a', 'n', 'u', 'n', ' ', 'b', 'a', 'l', 'e', 'n', 'c', 'i', 'a', 'g', 'a'])
#  list(['s', 'a', 'm', 'm', 'y', ' ', 'c', 'o', 'w', 'e', 'l', 'l'])
#  list(['s', 'a', 'r', 'a', ' ', 'm', 'a', 'l', 'a', 'k', 'u', 'l', ' ', 'l', 'a', 'n', 'e'])
#  list(['s', 'a', 'v', 'i', 'k', 'a', ' ', 'c', 'h', 'a', 'i', 'y', 'a', 'd', 'e', 'j'])
#  list(['s', 'i', 'n', 'j', 'a', 'i', ' ', 'p', 'l', 'e', 'n', 'g', 'p', 'a', 'n', 'i', 'c', 'h'])
#  list(['s', 'i', 'r', 'i', 'y', 'a', 'k', 'o', 'r', 'n', ' ', 'p', 'u', 'k', 'k', 'a', 'v', 'e', 's', 'h'])
#  list(['s', 'o', 'm', 'b', 'a', 't', ' ', 'm', 'e', 't', 'a', 'n', 'e', 'e'])
#  list(['s', 'o', 'm', 'l', 'e', 'k', ' ', 's', 'a', 'k', 'd', 'i', 'k', 'u', 'l'])
#  list(['s', 'o', 'n', 'i', 'a', ' ', 'c', 'o', 'u', 'l', 'i', 'n', 'g'])
#  list(['s', 'o', 'r', 'a', 'p', 'o', 'n', 'g', ' ', 'c', 'h', 'a', 't', 'r', 'e', 'e'])
#  list(['s', 'o', 'r', 'n', ' ', '(', 's', 'i', 'n', 'g', 'e', 'r', ')'])
#  list(['s', 'o', 'r', 'n', 'r', 'a', 'm', ' ', 't', 'e', 'p', 'p', 'i', 't', 'a', 'k'])
#  list(['s', 'r', 'i', 'r', 'i', 't', 'a', ' ', 'j', 'e', 'n', 's', 'e', 'n'])
#  list(['s', 't', 'e', 'l', 'l', 'a', ' ', 'm', 'a', 'l', 'u', 'c', 'c', 'h', 'i'])
#  list(['s', 'u', 'p', 'a', 'k', 's', 'o', 'r', 'n', ' ', 'c', 'h', 'a', 'i', 'm', 'o', 'n', 'g', 'k', 'o', 'l'])
#  list(['s', 'u', 'p', 'a', 'k', 'o', 'r', 'n', ' ', 'k', 'i', 't', 's', 'u', 'w', 'o', 'n'])
#  list(['s', 'u', 'n', 'n', 'y', ' ', 's', 'u', 'w', 'a', 'n', 'm', 'e', 't', 'h', 'a', 'n', 'o', 'n', 't'])
#  list(['s', 'u', 't', 'h', 'e', 'p', ' ', 'p', 'o', '-', 'n', 'g', 'a', 'm'])
#  list(['s', 'u', 'v', 'a', 'n', 'a', 'n', 't', ' ', 'k', 'o', 'n', 'g', 'y', 'i', 'n', 'g'])
#  list(['s', 'u', 'w', 'i', 'n', 'i', 't', ' ', 'p', 'a', 'n', 'j', 'a', 'm', 'a', 'w', 'a', 't'])
#  list(['t', 'a', 'n', 'i', 't', ' ', 'j', 'i', 't', 'n', 'u', 'k', 'u', 'l'])
#  list(['t', 'a', 't', 'a', ' ', 'y', 'o', 'u', 'n', 'g'])
#  list(['t', 'e', 'e', 'r', 'a', 'd', 'e', 't', 'h', ' ', 'w', 'o', 'n', 'g', 'p', 'u', 'a', 'p', 'u', 'n'])
#  list(['t', 'e', 'n'])
#  list(['t', 'e', 'r', 'a', ' ', 'p', 'a', 't', 'r', 'i', 'c', 'k'])
#  list(['t', 'h', 'e', 'e', 'r', 'a', 'd', 'e', 'j', ' ', 'w', 'o', 'n', 'g', 'p', 'u', 'a', 'p', 'a', 'n'])
#  list(['t', 'h', 'o', 'n', 'g', 'c', 'h', 'a', 'i', ' ', 'm', 'c', 'i', 'n', 't', 'y', 'r', 'e'])
#  list(['t', 'o', 'm', 'm', 'y', ' ', 'h', 'a', 't', 't', 'o'])
#  list(['t', 'o', 'n', 'y', ' ', 'j', 'a', 'a'])
#  list(['t', 'o', 'o', 'n', ' ', 'h', 'i', 'r', 'a', 'n', 'y', 'a', 's', 'a', 'p'])
#  list(['u', 'r', 'a', 's', 's', 'a', 'y', 'a', ' ', 's', 'p', 'e', 'r', 'b', 'u', 'n', 'd'])
#  list(['u', 't', 't', ' ', 'p', 'a', 'n', 'i', 'c', 'h', 'k', 'u', 'l'])
#  list(['v', 'i', 'o', 'l', 'e', 't', 't', 'e', ' ', 'w', 'a', 'u', 't', 'i', 'e', 'r'])
#  list(['w', 'i', 'l', 'l', 'y', ' ', 'm', 'c', 'i', 'n', 't', 'o', 's', 'h'])
#  list(['w', 'i', 'n', 'a', 'i', ' ', 'k', 'r', 'a', 'i', 'b', 'u', 't', 'r'])
#  list(['w', 'o', 'r', 'a', 'n', 'u', 't', ' ', 'w', 'o', 'n', 'g', 's', 'a', 'w', 'a', 'n'])
#  list(['w', 'o', 'r', 'a', 'r', 'a', 't', ' ', 's', 'u', 'w', 'a', 'n', 'n', 'a', 'r', 'a', 't'])
#  list(['a', 'l', 'e', 'x', ' ', 'a', 'l', 'b', 'o', 'n'])
#  list(['a', 'd', 'u', 'l', ' ', 'l', 'a', 'h', 's', 'o', 'h'])
#  list(['a', 'j', 'c', 'h', 'a', 'r', 'a', 'p', 'o', 'r', 'n', ' ', 'k', 'o', 'n', 'g', 'y', 'o', 't'])
#  list(['a', 'm', 'a', 'n', 'd', 'a', ' ', 'm', 'i', 'l', 'd', 'r', 'e', 'd', ' ', 'c', 'a', 'r', 'r'])
#  list(['a', 'u', 'g', 'u', 's', 't', ' ', 'g', 'u', 's', 't', 'a', 'f', 's', 's', 'o', 'n', ' ', 'l', 'o', 'h', 'a', 'p', 'r', 'a', 's', 'e', 'r', 't'])
#  list(['c', 'h', 'a', 'n', 'a', 't', 'h', 'i', 'p', ' ', 's', 'o', 'n', 'g', 'k', 'r', 'a', 's', 'i', 'n'])
#  list(['c', 'h', 'a', 'n', 'a', 't', 'i', 'p', ' ', 's', 'o', 'n', 'k', 'h', 'a', 'm'])
#  list(['c', 'h', 'a', 'r', 'y', 'l', ' ', 'c', 'h', 'a', 'p', 'p', 'u', 'i', 's'])
#  list(['c', 'h', 'a', 't', 'c', 'h', 'u', '-', 'o', 'n', ' ', 'm', 'o', 'k', 's', 'r', 'i'])
#  list(['e', 'r', 'n', 'e', 's', 't', 'o', ' ', 'a', 'm', 'a', 'n', 't', 'e', 'g', 'u', 'i', ' ', 'p', 'h', 'u', 'm', 'i', 'p', 'h', 'a'])
#  list(['k', 'a', 'r', 'i', 'n', 'a', ' ', 'k', 'r', 'a', 'u', 's', 'e'])
#  list(['k', 'a', 'w', 'i', 'n', ' ', 't', 'h', 'a', 'm', 's', 'a', 't', 'c', 'h', 'a', 'n', 'a', 'n'])
#  list(['k', 'e', 'v', 'i', 'n', ' ', 'd', 'e', 'e', 'r', 'o', 'm', 'r', 'a', 'm'])
#  list(['k', 'i', 's', 's', 'a', 'd', 'a', ' ', 'n', 'i', 'l', 's', 'a', 'w', 'a', 'i'])
#  list(['m', 'a', 'l', 'i', 'k', 'a', ' ', 'k', 'a', 'n', 't', 'h', 'o', 'n', 'g'])
#  list(['m', 'a', 'n', 'u', 'e', 'l', ' ', 'b', 'i', 'h', 'r'])
#  list(['m', 'a', 'r', 'c', 'o', ' ', 'b', 'a', 'l', 'l', 'i', 'n', 'i'])
#  list(['m', 'i', 'k', 'a', ' ', 'c', 'h', 'u', 'n', 'u', 'o', 'n', 's', 'e', 'e'])
#  list(['m', 'u', 'h', 'a', 'm', 'm', 'a', 'd', ' ', 'o', 's', 'a', 'm', 'a', 'n', 'm', 'u', 's', 'a'])
#  list(['n', 'a', 'r', 'i', 's', 's', 'a', 'p', 'a', 't', ' ', 'l', 'a', 'm'])
#  list(['n', 'o', 'o', 't', 's', 'a', 'r', 'a', ' ', 't', 'o', 'm', 'k', 'o', 'm'])
#  list(['p', 'a', 'n', 'i', 'p', 'a', 'k', ' ', 'w', 'o', 'n', 'g', 'p', 'a', 't', 't', 'a', 'n', 'a', 'k', 'i', 't'])
#  list(['p', 'a', 't', 'r', 'i', 'c', 'k', ' ', 'a', 'a', 'l', 't', 'o', 'n', 'e', 'n'])
#  list(['p', 'h', 'i', 'l', 'i', 'p', ' ', 'r', 'o', 'l', 'l', 'e', 'r'])
#  list(['p', 'i', 'm', 'p', 'i', 'c', 'h', 'a', 'y', 'a', ' ', 'k', 'o', 'k', 'r', 'a', 'm'])
#  list(['p', 'l', 'e', 'u', 'm', 'j', 'i', 't', ' ', 't', 'h', 'i', 'n', 'k', 'a', 'o', 'w'])
#  list(['r', 'a', 't', 'c', 'h', 'a', 'n', 'o', 'k', ' ', 'i', 'n', 't', 'a', 'n', 'o', 'n'])
#  list(['s', 'a', 'n', 'd', 'y', ' ', 's', 't', 'u', 'v', 'i', 'k'])
#  list(['s', 'a', 'r', 'a', 'c', 'h', ' ', 'y', 'o', 'o', 'y', 'e', 'n'])
#  list(['s', 'u', 'p', 'a', 'c', 'h', 'a', 'i', ' ', 'j', 'a', 'i', 'd', 'e', 'd'])
#  list(['t', 'a', 'm', 'a', 'r', 'i', 'n', 'e', ' ', 't', 'a', 'n', 'a', 's', 'u', 'g', 'a', 'r', 'n'])
#  list(['t', 'h', 'e', 'e', 'r', 'a', 't', 'h', 'o', 'n', ' ', 'b', 'u', 'n', 'm', 'a', 't', 'h', 'a', 'n'])
#  list(['t', 'i', 'f', 'f', 'a', 'n', 'y', ' ', 'b', 'i', 'a', 's'])
#  list(['t', 'r', 'i', 's', 't', 'a', 'n', ' ', 'd', 'o'])
#  list(['a', 'p', 'i', 'r', 'a', 'k', ' ', 'k', 'o', 's', 'a', 'y', 'o', 't', 'h', 'i', 'n'])
#  list(['j', 'o', 'n', ' ', 'u', 'n', 'g', 'p', 'a', 'k', 'o', 'r', 'n'])
#  list(['l', 'a', 'd', 'y', ' ', 'm', 'e', 'r', 'i', 'a', 'm'])
#  list(['j', 'a', 'm', 'e', 's', ' ', 'y', 'e', 'n', 'b', 'a', 'm', 'r', 'o', 'o', 'n', 'g'])
#  list(['o', 'm', 'm', 'i', ' ', 'p', 'i', 'p', 'i', 't', '-', 's', 'u', 'k', 's', 'u', 'n'])
#  list(['l', 'i', 's', 't', ' ', 'o', 'f', ' ', 't', 'h', 'a', 'i', ' ', 'a', 'c', 't', 'r', 'e', 's', 's', 'e', 's'])
#  list(['l', 'i', 's', 't', ' ', 'o', 'f', ' ', 't', 'h', 'a', 'i', ' ', 'a', 'c', 't', 'o', 'r', 's'])
#  list(['l', 'i', 's', 't', ' ', 'o', 'f', ' ', 't', 'h', 'a', 'i', ' ', 'f', 'i', 'l', 'm', ' ', 'd', 'i', 'r', 'e', 'c', 't', 'o', 'r', 's'])
#  list(['l', 'i', 's', 't', ' ', 'o', 'f', ' ', 'p', 'r', 'i', 'm', 'e', ' ', 'm', 'i', 'n', 'i', 's', 't', 'e', 'r', 's', ' ', 'o', 'f', ' ', 't', 'h', 'a', 'i', 'l', 'a', 'n', 'd'])
#  list(['c', 'a', 't', 'e', 'g', 'o', 'r', 'y', ':', 't', 'h', 'a', 'i', ' ', 'r', 'o', 'y', 'a', 'l', 't', 'y'])
#  list(['l', 'i', 's', 't', 's', ' ', 'o', 'f', ' ', 'p', 'e', 'o', 'p', 'l', 'e', ' ', 'b', 'y', ' ', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l', 'i', 't', 'y'])
#  list(['l', 'i', 's', 't', 's', ' ', 'o', 'f', ' ', 't', 'h', 'a', 'i', ' ', 'p', 'e', 'o', 'p', 'l', 'e'])]

# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.datasets import imdb

max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Loading data...
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)
# Build model...
# Train...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/15
# 25000/25000 [==============================] - 104s 4ms/step - loss: 0.4597 - acc: 0.7810 - val_loss: 0.4226 - val_acc: 0.8234
# Epoch 2/15
# 25000/25000 [==============================] - 101s 4ms/step - loss: 0.3008 - acc: 0.8777 - val_loss: 0.3770 - val_acc: 0.8316
# Epoch 3/15
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.2171 - acc: 0.9149 - val_loss: 0.4154 - val_acc: 0.8292
# Epoch 4/15
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.1553 - acc: 0.9420 - val_loss: 0.4811 - val_acc: 0.8285
# Epoch 5/15
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.1059 - acc: 0.9619 - val_loss: 0.5647 - val_acc: 0.8218
# Epoch 6/15
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.0744 - acc: 0.9740 - val_loss: 0.6779 - val_acc: 0.8210
# Epoch 7/15
# 25000/25000 [==============================] - 103s 4ms/step - loss: 0.0538 - acc: 0.9820 - val_loss: 0.8110 - val_acc: 0.8168
# Epoch 8/15
# 25000/25000 [==============================] - 103s 4ms/step - loss: 0.0489 - acc: 0.9833 - val_loss: 0.7868 - val_acc: 0.8196
# Epoch 9/15
# 25000/25000 [==============================] - 102s 4ms/step - loss: 0.0354 - acc: 0.9881 - val_loss: 0.7864 - val_acc: 0.8114
# Epoch 10/15
# 25000/25000 [==============================] - 101s 4ms/step - loss: 0.0296 - acc: 0.9902 - val_loss: 0.9543 - val_acc: 0.8134
# Epoch 11/15
# 25000/25000 [==============================] - 102s 4ms/step - loss: 0.0230 - acc: 0.9922 - val_loss: 0.9028 - val_acc: 0.8154
# Epoch 12/15
# 25000/25000 [==============================] - 101s 4ms/step - loss: 0.0154 - acc: 0.9956 - val_loss: 0.9387 - val_acc: 0.8129
# Epoch 13/15
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.0116 - acc: 0.9961 - val_loss: 1.0770 - val_acc: 0.8144
# Epoch 14/15
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.0115 - acc: 0.9967 - val_loss: 1.1106 - val_acc: 0.8108
# Epoch 15/15
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.0078 - acc: 0.9972 - val_loss: 1.1513 - val_acc: 0.8096
# 25000/25000 [==============================] - 10s 398us/step
# Test score: 1.151297209488228
# Test accuracy: 0.80964
